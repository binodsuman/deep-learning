# %% [markdown]
# # Binod Suman Academy YouTube

# %%
import numpy as np
from numpy import asarray

data = [[3,3,2,1,0],
		[0,0,1,3,1],
		[3,1,2,2,3],
		[2,0,0,2,2],
		[2,0,0,0,1]]
data = np.asarray(data)
data = data.reshape(1, 5, 5, 1)

kernel = [[[[0]],[[1]],[[2]]],
            [[[2]],[[2]],[[0]]],
            [[[0]],[[1]],[[2]]]]
weights = [asarray(kernel), asarray([0.0])]

# %%
from IPython.display import Image
Image(filename='kernel.jpg')

# %%
from keras.models import Sequential
from keras.layers import Conv2D
# create model
model = Sequential()
model.add(Conv2D(1, (3,3),  input_shape=(5, 5, 1)))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 3, 3, 1)           10
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.set_weights(weights)
yhat = model.predict(data)
for r in range(yhat.shape[1]):
	print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# [12.0, 12.0, 17.0]
# [10.0, 17.0, 19.0]
# [9.0, 6.0, 14.0]

# %%
Image(filename='kernel_2.jpg')

# %%
Image(filename='stride.jpg')

# %%
model = Sequential()
model.add(Conv2D(1, (3,3), strides=(2, 2), input_shape=(5, 5, 1)))
model.summary()
model.set_weights(weights)
yhat = model.predict(data)
for r in range(yhat.shape[1]):
	print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 2, 2, 1)           10
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# [12.0, 17.0]
# [9.0, 14.0]

# %%
Image(filename='padding.jpg')

# %%
model = Sequential()
model.add(Conv2D(1, (3,3), padding='same', input_shape=(5, 5, 1)))
model.summary()
model.set_weights(weights)
yhat = model.predict(data)
for r in range(yhat.shape[1]):
	print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 5, 5, 1)           10
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# [6.0, 14.0, 17.0, 11.0, 3.0]
# [14.0, 12.0, 12.0, 17.0, 11.0]
# [8.0, 10.0, 17.0, 19.0, 13.0]
# [11.0, 9.0, 6.0, 14.0, 12.0]
# [6.0, 4.0, 4.0, 6.0, 4.0]

# %%
Image(filename='max_pooling.jpg')

# %%
from keras.layers import MaxPooling2D
model = Sequential()
model.add(Conv2D(1, (3,3), padding='same', input_shape=(5, 5, 1)))
model.add(MaxPooling2D((2,2)))
model.summary()
model.set_weights(weights)
yhat = model.predict(data)
for r in range(yhat.shape[1]):
	print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 5, 5, 1)           10
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 1)           0
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# [14.0, 17.0]
# [11.0, 19.0]

# %%
Image(filename='avg_pooling.jpg')

# %%
from keras.layers import AveragePooling2D
model = Sequential()
model.add(Conv2D(1, (3,3), padding='same', input_shape=(5, 5, 1)))
model.add(AveragePooling2D((2,2)))
model.summary()
model.set_weights(weights)
yhat = model.predict(data)
for r in range(yhat.shape[1]):
	print([yhat[0,r,c,0] for c in range(yhat.shape[2])])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 5, 5, 1)           10
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 2, 2, 1)           0
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# [11.5, 14.25]
# [9.5, 14.0]

# %%
from keras.layers import Flatten
model = Sequential()
model.add(Conv2D(1, (3,3), padding='same', input_shape=(5, 5, 1)))
model.add(AveragePooling2D((2,2)))
model.add(Flatten())
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 5, 5, 1)           10
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 2, 2, 1)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4)                 0
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Thank you, please subscribe Binod Suman Academy YouTube Channel :)
